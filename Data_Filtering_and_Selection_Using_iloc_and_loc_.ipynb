# %% [markdown]
# <a href="https://colab.research.google.com/github/Benbuk/GOMYCODE_DS_Bootcamp/blob/main/Data_Filtering_and_Selection_Using_iloc_and_loc_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Frame Filtering and Selection Using iloc and loct**
#
# Create a dataframe called "employee_df" with the following data:
#
# import pandas as pd
#
# >data = {'Name': ['John', 'Mary', 'Bob', 'Sarah', 'Tom', 'Lisa'], 'Department': ['IT', 'Marketing', 'Sales', 'IT', 'Finance', 'Marketing'], 'Age': [30, 40, 25, 35, 45, 28], 'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'], 'Salary': [50000, 60000, 45000, 55000, 70000, 55000], 'Experience': [3, 7, 2, 5, 10, 4]}
#
#  employee_df = pd.DataFrame(data)
#
#
# 1. Use the iloc method to select the first 3 rows of the dataframe.
# 2. Use the loc method to select all rows where the Department is "Marketing".
# 3. Use the iloc method to select the Age and Gender columns for the first 4 rows of the dataframe.
# 4. Use the loc method to select the Salary and Experience columns for all rows where the Gender is "Male".
#
# Note:
#
# iloc is used for selection by index location
# loc is used for selection by label.

# %%
#installing pandas
# !pip install pandas
import pandas as pd

data = {'Name': ['John', 'Mary', 'Bob', 'Sarah', 'Tom', 'Lisa'], 'Department': ['IT', 'Marketing', 'Sales', 'IT', 'Finance', 'Marketing'], 'Age': [30, 40, 25, 35, 45, 28], 'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female'], 'Salary': [50000, 60000, 45000, 55000, 70000, 55000], 'Experience': [3, 7, 2, 5, 10, 4]}

employee_df = pd.DataFrame(data)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
#view dataframe
employee_df
# Out:
#     Name Department  Age  Gender  Salary  Experience
# 0   John         IT   30    Male   50000           3
# 1   Mary  Marketing   40  Female   60000           7
# 2    Bob      Sales   25    Male   45000           2
# 3  Sarah         IT   35  Female   55000           5
# 4    Tom    Finance   45    Male   70000          10
# 5   Lisa  Marketing   28  Female   55000           4

# %%
#selects the first 3 rows
employee_df.iloc[3]
employee_df.loc[employee_df['Department'] == 'Marketing']
# Out:
#    Name Department  Age  Gender  Salary  Experience
# 1  Mary  Marketing   40  Female   60000           7
# 5  Lisa  Marketing   28  Female   55000           4

# %%
#selects rows where department is marketing
employee_df.loc[employee_df['Department'].isin(['Marketing'])]
# Out:
#    Name Department  Age  Gender  Salary  Experience
# 1  Mary  Marketing   40  Female   60000           7
# 5  Lisa  Marketing   28  Female   55000           4

# %%
#selects the first 4 rows of the age and gender column
employee_df.iloc[0:4,2:4]
# Out:
#    Age  Gender
# 0   30    Male
# 1   40  Female
# 2   25    Male
# 3   35  Female

# %%
#selects the salary and experience column where gender is male
employee_df.loc[employee_df['Gender'] == 'Male', ['Salary', 'Experience']]
# Out:
#    Salary  Experience
# 0   50000           3
# 2   45000           2
# 4   70000          10
